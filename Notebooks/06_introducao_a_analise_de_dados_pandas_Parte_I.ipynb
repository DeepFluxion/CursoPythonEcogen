# %% [markdown]
# [link](https://www.kaggle.com/code/joaoavf/introducao-a-analise-de-dados-python-e-pandas)

# %% [markdown]
# # Excelente estamos avançando 🤩🙌👏
#
# 🧑‍🎓🧑🏿‍🎓🧑🏻‍🎓🧑🏾‍🎓🧑🏼‍🎓🧑🏽‍🎓
#
# Vimos muita coisa em nossas conversas!! Nos aprofundamos bastante no Python, vimos desde conceitos básciso com tipos de dados, passamos por estruturas de decisão (`IF ELSE`), estruturas de repetição (`WHILE`e `FOR`), coleções como listas, tupas e dicionários e na última conversa vimos como criar funções utilizando o comando `def`.
#
# Hoje vamos rever nosso desafio e tambéms vamos inciar nossa jornada pela principal ferrameta de análise de dados a bbioteca [Pandas](https://pandas.pydata.org/)
#
# O Material desta aula foi baseado no tutorial criado por JOÃO ALEXANDRE VAZ FERREIRA no site [kaggle](https://www.kaggle.com/) disponível neste [link](https://www.kaggle.com/code/joaoavf/introducao-a-analise-de-dados-python-e-pandas)

# %% [markdown]
# # Nosso novo desafio
#
# Crie as seguintes funções :
# a) `cria_lista()` uma função que interaja com o usuário para inserir uma lista de números e retorne essa lista
# b) `maior_numero()` retorna o maior elemento
# c) `menor_numero()` retorna o menor elemento
# d) `numero_pares()` retorna uma lista contendo números pares
# e) `calcula_media()` retorna a média de uma lista
# f) `calcula_soma()` retorna a soma de uma lista
# g) `n_elementos()` retorna o numero de elementos uma lista
# h) `calcula_desv_pad()` retorna o desvio padrão de uma lista
#
# Esse é um bom desafio!!! Na semana que vem vamos ver como fazer isto!!

# %%
# a) cria_lista() uma função que interaja com o usuário para inserir uma lista de números e retorne essa lista

def cria_lista():
    # Cria a lista 
    n = int(input("Quantos números terá a lista: ")) # pergunte quantos núeros terá a lista e armazene em n
    print('+---------------------------------------------------------------+')
    print(f"A Lista terá {n} números")# informe a quantidade de números da lista para o usuários
    lista = [] #crie uma lista vazia
    for i in range(n): #Loop para repetir o n vezes a entrada da lista
        x = float(input(f"Qual o item {i} da lista: ")) #pergunte qual é o item i da lista
        lista.append(x) #adicione o item x à lista
    return lista

# %%
# Criando uma lista
cria_lista()
# Out:
# Quantos números terá a lista: 10
# +---------------------------------------------------------------+
# A Lista terá 10 números
# Qual o item 0 da lista: -3
# Qual o item 1 da lista: -2
# Qual o item 2 da lista: -1
# Qual o item 3 da lista: 0
# Qual o item 4 da lista: 1
# Qual o item 5 da lista: 2
# Qual o item 6 da lista: 3
# Qual o item 7 da lista: -3
# Qual o item 8 da lista: -2
# Qual o item 9 da lista: -1
# [-3.0, -2.0, -1.0, 0.0, 1.0, 2.0, 3.0, -3.0, -2.0, -1.0]

# %%
# Mas como chamar esta lista ?
lista
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17496\2357709383.py in <module>
#       1 # Mas como chamar esta lista ?
# ----> 2 lista
#
# NameError: name 'lista' is not defined

# %%
# fazendo do jeto certo
lista = cria_lista()
# Out:
# Quantos números terá a lista: 10
# +---------------------------------------------------------------+
# A Lista terá 10 números
# Qual o item 0 da lista: -3
# Qual o item 1 da lista: -2
# Qual o item 2 da lista: -1
# Qual o item 3 da lista: 0
# Qual o item 4 da lista: 1
# Qual o item 5 da lista: 2
# Qual o item 6 da lista: 3
# Qual o item 7 da lista: -3
# Qual o item 8 da lista: -2
# Qual o item 9 da lista: -1

# %%
# Visualizando a lista
print(lista)
# Out:
# [-3.0, -2.0, -1.0, 0.0, 1.0, 2.0, 3.0, -3.0, -2.0, -1.0]

# %%
# b) maior_numero() retorna o maior elemento
def maior_numero(lista): # Temos um parâmetro aqui a lista de qual iremos selecionar o maiuor número
    maior_numero = max(lista) # Armazenando o maior número
    print('+---------------------------------------------------------------+')
    print(f'O maior valor é {maior_numero}')
    return maior_numero # retorna o maior numero

# %%
maior_numero = maior_numero(lista)
# Out:
# +---------------------------------------------------------------+
# O maior valor é 3.0

# %%
# c) menor_numero() retorna o menor elemento
def menor_numero(lista): # Temos um parâmetro aqui a lista de qual iremos selecionar o menor número
    menor_numero = min(lista) # Armazenando o menor número
    print('+---------------------------------------------------------------+')
    print(f'O menor valor é {menor_numero}')
    return menor_numero # retorna o menor numero

# %%
menor_numero = menor_numero(lista)
# Out:
# +---------------------------------------------------------------+
# O menor valor é -3.0

# %%
# d) numero_pares() retorna uma lista contendo números pares
def numero_pares(lista): # Temos um parâmetro aqui a lista de qual iremos selecionar os números pares
    lista_pares = [] # Cria uma lista vazia para armazenar os numeros pares
    # Loop para percorrer a lista
    print('+---------------------------------------------------------------+')
    for item in lista:
    # verificando se resto da divisão com do item por 2 é 0 com o operador módulo %
        e_par = item%2==0 
        if e_par: # se o resultado for verdadeiro executa estas funções
            print(f'o número {item} é um número par') # imprimindo o item par
            lista_pares.append(item)
    return lista_pares

# %%
lista_pares = numero_pares(lista)
# Out:
# +---------------------------------------------------------------+
# o número -2.0 é um número par
# o número 0.0 é um número par
# o número 2.0 é um número par
# o número -2.0 é um número par

# %%
print(lista_pares)
# Out:
# [-2.0, 0.0, 2.0, -2.0]

# %%
# e) calcula_media() retorna a média de uma lista
def calcula_media(lista): # Temos um parâmetro aqui a lista de qual iremos selecionar os números pares
    print('+---------------------------------------------------------------+')
    print(f'a média dos elementos da lista é : {sum(lista)/len(lista)}')
    return sum(lista)/len(lista)

# %%
media = calcula_media(lista)
print(media)
# Out:
# +---------------------------------------------------------------+
# a média dos elementos da lista é : -0.6
# -0.6

# %%
calcula_media(lista_pares)
print(media)
# Out:
# +---------------------------------------------------------------+
# a média dos elementos da lista é : -0.5
# -0.6

# %%
# e) calcula_soma() retorna a soma de uma lista
def calcula_soma(lista): # Temos um parâmetro aqui a lista de qual iremos somar os elementos
    print('+---------------------------------------------------------------+')
    print(f'a soma dos elementos da lista é : {sum(lista)}')
    return sum(lista)

# %%
soma = calcula_soma(lista)
print(soma)
# Out:
# +---------------------------------------------------------------+
# a soma dos elementos da lista é : -6.0
# -6.0

# %%
# f) n_elementos() retorna a quantidade de elementos de uma lista
def n_elementos(lista): # Temos um parâmetro aqui a lista de qual iremos contar os elementos
    print('+---------------------------------------------------------------+')
    print(f'o numero de elementos da lista é : {len(lista)}')
    return len(lista)

# %%
n_elem = n_elementos(lista)
print(n_elem)
# Out:
# +---------------------------------------------------------------+
# o numero de elementos da lista é : 10
# 10

# %% [markdown]
# # O que é o desvio-padrão?
#
# O desvio-padrão é uma medida de dispersão do conjunto, ou seja, uma medida que indica quão uniformes são os dados do conjunto. O desvio-padrão demonstra a distância dos valores em relação à média do conjunto, quanto mais próximo de 0 for o desvio-padrão, menos dispersos são os dados daquele conjunto. O desvio-padrão pode ser representado por $Dp$ ou pela letra grega $\sigma$ (sigma).
#
# De modo geral, temos que:
# - Quanto maior o desvio-padrão, **mais** dispersos são os dados do conjunto (menos regular, menos homogêneo).
# - Quanto menor o desvio-padrão, **menos** dispersos são os dados do conjunto (mais regular, mais homogêneo).

# %% [markdown]
# ## Fórmula do desvio-padrão
# A fórmula para calcular o desvio-padrão é:
#
# $$
# \sigma = \sqrt(\frac{\sum_{i=0}^{n}(x_{i} - \bar{x})^2}{n})
# $$
#
# - $\sigma$: desvio-padrão
#
# - $n$: quantidade de elementos no conjunto
#
# - $x_i$: elementos do conjunto
#
# - $\bar{x}$: média do conjunto
#
# A fórmula diz que o desvio-padrão é a raiz quadrada da somatória da diferença entre cada um dos elementos do conjunto com a média, dividido pela quantidade de elementos do conjunto.

# %% [markdown]
# # Calculando o desvio padrão de uma lista
#
# 1. Para calcular a raiz quadrada de um número o python já tem uma função implementada chamada `sqrt()` para usá-la temos de importar o módulo `math`, da seguinte forma:
# ```python
# import math
# num = float(input("Entre com um número:\n"))
# raiz = math.sqrt(num)
# print(f'\nA raiz quadrada de {num} é {raiz}\n')
# ```

# %% [markdown]
# 2. Para calcular $(x_{i} - \bar{x})$ temos de calcular a média (usando nossa função calcula_media(lista) e subtrair de cada elemento i da lista e elevar ao quadro, o que em Python seria:
#
# ```python
# lista_dif = [] #cria uma lista vazia
# media = calcula_media(lista) #calcula a media
#
# for i in range(len(lista)): #percorre a lista gerando indices
#     dif = lista[i]-media # calcula a diferença com a media
#     lista_dif.append(dif**2) # calcula o quadrado da diferença e adiciona à lista
# ```

# %% [markdown]
# 3. Calcula a raiz quadrada com `math.sqrt()` da soma das diferenças $\sqrt{\sum_{i=0}^{n}(x_{i} - \bar{x})^2}$ em python temos:
# ```python
# soma_dif = calcula_soma(lista_dif) # somatório das diferenças de lista_dif
# raiz = math.sqrt(soma_dif) # Calcula raiz quadrada da soma de lista dif
# sigma = raiz/n_elementos(lista) # divide raiz pelo numero de elementos de lista (ou de lista_dif)
# ```

# %% [markdown]
# # Colocando tudo junto numa função

# %%
import math

def calcula_desv_pad(lista):
    # Passo 1
    lista_dif = [] #cria uma lista vazia
    media = calcula_media(lista) #calcula a media
    
    for i in range(len(lista)): #percorre a lista gerando indices
        dif = lista[i]-media # calcula a diferença com a media
        lista_dif.append(dif**2) # calcula o quadrado da diferença e adiciona à lista
    # Passo 2
    soma_dif = calcula_soma(lista_dif) # somatório das diferenças de lista_dif
    raiz = math.sqrt(soma_dif) # Calcula raiz quadrada da soma de lista dif
    sigma = raiz/n_elementos(lista) # divide raiz pelo numero de elementos de lista (ou de lista_dif)
    print('+---------------------------------------------------------------+')
    print(f'o desvio padrão da lista é : {sigma}')
    return sigma

# %%
sigma = calcula_desv_pad(lista)
# Out:
# +---------------------------------------------------------------+
# a média dos elementos da lista é : -0.6
# +---------------------------------------------------------------+
# a soma dos elementos da lista é : 38.4
# +---------------------------------------------------------------+
# o numero de elementos da lista é : 10
# +---------------------------------------------------------------+
# o desvio padrão da lista é : 0.6196773353931867

# %% [markdown]
# # Iniciando com o Pandas

# %%
# Importando as bibliotecas do pandas
import pandas as pd
import seaborn as sns

# %% [markdown]
# Vamos imaginar que você foi a um supermercado com uma lista de suas compras semanais, a cada semana você controla estas compras
# ```python
# items_lista = ['mostarda','kethchup', 'maçã', 'banana', 'pizza', 'queijo', 'presunto']
# precos_lista_semana_1 = [10.00, 12.00, 15.00, 20.00, 25.00, 30.00, 45.00]
# precos_lista_semana_2 = [11.00, 20.00, 18.00, 20.00, 24.00, 35.00, 54.00]
# precos_lista_semana_3 = [15.00, 22.00, 25.00, 40.00, 26.00, 39.00, 48.00]
# precos_lista_semana_4 = [10.00, 9.00, 14.00, 30.00, 27.00, 46.00, 42.00]
# ```

# %% [markdown]
# Pode ser um pouco dificil trabalhar com tantas listas, o Pandas nos permite trabalhar com uma estrutura de dados diferente que são os `DataFrames`, que são muito similares às planilhas do excel. Uma planilha possui muitas linhas e muitas columnas, para começar vamos criar um `DataFrame` especial que são as `Series`que são `DataFrames` de apenas uma coluna e que podem ser criados a partir de listas com a função `pd.Series()`. Vamos criar as listas:

# %%
items_lista = ['mostarda','kethchup', 'maçã', 'banana', 'pizza', 'queijo', 'presunto']
precos_lista_semana_1 = [10.00, 12.00, 15.00, 20.00, 25.00, 30.00, 45.00]
precos_lista_semana_2 = [11.00, 20.00, 18.00, 20.00, 24.00, 35.00, 54.00]
precos_lista_semana_3 = [15.00, 22.00, 25.00, 40.00, 26.00, 39.00, 48.00]
precos_lista_semana_4 = [10.00, 9.00, 14.00, 30.00, 27.00, 46.00, 42.00]

# %%
# Criando a primeira série
s1 = pd.Series(precos_lista_semana_1)
s1
# Out:
# 0    10.0
# 1    12.0
# 2    15.0
# 3    20.0
# 4    25.0
# 5    30.0
# 6    45.0
# dtype: float64

# %%
# Criando as demais séries
s2 = pd.Series(precos_lista_semana_2)
s3 = pd.Series(precos_lista_semana_3)
s4 = pd.Series(precos_lista_semana_4)

# %%
print(s1)
# Out:
# 0    10.0
# 1    12.0
# 2    15.0
# 3    20.0
# 4    25.0
# 5    30.0
# 6    45.0
# dtype: float64

# %%
print(s2)
# Out:
# 0    11.0
# 1    20.0
# 2    18.0
# 3    20.0
# 4    24.0
# 5    35.0
# 6    54.0
# dtype: float64

# %%
print(s3)
# Out:
# 0    15.0
# 1    22.0
# 2    25.0
# 3    40.0
# 4    26.0
# 5    39.0
# 6    48.0
# dtype: float64

# %%
print(s4)
# Out:
# 0    10.0
# 1     9.0
# 2    14.0
# 3    30.0
# 4    27.0
# 5    46.0
# 6    42.0
# dtype: float64

# %% [markdown]
# > Cada serie indica uma semana de compras e está disposta numa coluna, cada linha é um item ordenado do preço pago naquela semana em cada um dos itens da lista. por exemplo se você quisesse saber qunato pagou por um determinado item em cada uma das semanas você faria o seguinte, sabendo que cada série representa uma semana e cada linha da série é  o valor pago por um item, os valores pagos pelo item 0 mostarda são:

# %%
print(f'Na semana 1 você pagou por mostarda {s1[0]} reais')
print(f'Na semana 2 você pagou por mostarda {s2[0]} reais')
print(f'Na semana 3 você pagou por mostarda {s3[0]} reais')
print(f'Na semana 4 você pagou por mostarda {s4[0]} reais')
# Out:
# Na semana 1 você pagou por mostarda 10.0 reais
# Na semana 2 você pagou por mostarda 11.0 reais
# Na semana 3 você pagou por mostarda 15.0 reais
# Na semana 4 você pagou por mostarda 10.0 reais

# %% [markdown]
# Se você quiser maior flexibilidade você pode pesquisar o indice de um item na lista `itens_lista` e buscar o valor desta linha em cada uma das séries

# %%
item = 'presunto'
indice_item = items_lista.index(item)
print(f' O indice de {item} é {indice_item}')
print(f'Na semana 1 você pagou por {item} {s1[indice_item]} reais')
print(f'Na semana 2 você pagou por {item} {s2[indice_item]} reais')
print(f'Na semana 3 você pagou por {item} {s3[indice_item]} reais')
print(f'Na semana 4 você pagou por {item} {s4[indice_item]} reais')
# Out:
#  O indice de presunto é 6
# Na semana 1 você pagou por presunto 45.0 reais
# Na semana 2 você pagou por presunto 54.0 reais
# Na semana 3 você pagou por presunto 48.0 reais
# Na semana 4 você pagou por presunto 42.0 reais

# %% [markdown]
# O pandas permite que você crie um indice para as linhas que não precisa ser um número, basta usar o atributo `index`

# %%
s1.index=items_lista
s1
# Out:
# mostarda    10.0
# kethchup    12.0
# maçã        15.0
# banana      20.0
# pizza       25.0
# queijo      30.0
# presunto    45.0
# dtype: float64

# %% [markdown]
#  e agora

# %%
print(s1['mostarda'])
print(s1['queijo'])
print(s1['presunto'])
# Out:
# 10.0
# 30.0
# 45.0

# %% [markdown]
# se fizermos o mesmo para todas as séries

# %%
s2.index=items_lista
s3.index=items_lista
s4.index=items_lista

# %% [markdown]
# Assim simplificamos nossas pesquisa fazendo:

# %%
item = 'presunto'
print(f'Na semana 1 você pagou por {item} {s1[item]} reais')
print(f'Na semana 2 você pagou por {item} {s2[item]} reais')
print(f'Na semana 3 você pagou por {item} {s3[item]} reais')
print(f'Na semana 4 você pagou por {item} {s4[item]} reais')
# Out:
# Na semana 1 você pagou por presunto 45.0 reais
# Na semana 2 você pagou por presunto 54.0 reais
# Na semana 3 você pagou por presunto 48.0 reais
# Na semana 4 você pagou por presunto 42.0 reais

# %% [markdown]
# Também podemos criar um Dataframe da seguinte forma:

# %%
df = pd.DataFrame([s1,s2,s3,s4])
df
# Out:
#    mostarda  kethchup  maçã  banana  pizza  queijo  presunto
# 0      10.0      12.0  15.0    20.0   25.0    30.0      45.0
# 1      11.0      20.0  18.0    20.0   24.0    35.0      54.0
# 2      15.0      22.0  25.0    40.0   26.0    39.0      48.0
# 3      10.0       9.0  14.0    30.0   27.0    46.0      42.0

# %% [markdown]
# Observe que `df` possui colunas que representam os itens comprados e linhas a semana e podemos deixar nosso `DataFrame` mais bacana se fizermos:

# %%
df.index = ['W1','W2','W3','W4']
df
# Out:
#     mostarda  kethchup  maçã  banana  pizza  queijo  presunto
# W1      10.0      12.0  15.0    20.0   25.0    30.0      45.0
# W2      11.0      20.0  18.0    20.0   24.0    35.0      54.0
# W3      15.0      22.0  25.0    40.0   26.0    39.0      48.0
# W4      10.0       9.0  14.0    30.0   27.0    46.0      42.0

# %% [markdown]
# Usando `loc[linha,coluna]`, podemos fazer um pesquisa assim:

# %%
print(df.loc['W1','mostarda'])
# Out:
# 10.0

# %%
item = 'presunto'
for semana in df.index:
    print(f'Na semana {semana} você pagou por {df.loc[semana,item]} reais')
# Out:
# Na semana W1 você pagou por 45.0 reais
# Na semana W2 você pagou por 54.0 reais
# Na semana W3 você pagou por 48.0 reais
# Na semana W4 você pagou por 42.0 reais

# %%
df.loc[['W1','W2'],['queijo','presunto']]
# Out:
#     queijo  presunto
# W1    30.0      45.0
# W2    35.0      54.0

# %%
# Se vc quiser fazer a soma, média, desvio padrão de um item:
item = 'presunto'
print(f'A soma de gastos com {item} foi {df[item].sum()}')
print(f'A média de gastos com {item} foi {df[item].mean()}')
print(f'O desvio padrão de gastos com {item} foi {df[item].std()}')
print(f'O máximo de gastos com {item} foi {df[item].max()}')
print(f'O mínimo de gastos com {item} foi {df[item].min()}')
# Out:
# A soma de gastos com presunto foi 189.0
# A média de gastos com presunto foi 47.25
# O desvio padrão de gastos com presunto foi 5.123475382979799
# O máximo de gastos com presunto foi 54.0
# O mínimo de gastos com presunto foi 42.0

# %% [markdown]
# Ou ainda:

# %%
for item in df.columns:
    print('+--------------------------------------------------+')
    print(f'A soma de gastos com {item} foi {df[item].sum()}')
    print(f'A média de gastos com {item} foi {df[item].mean()}')
    print(f'O desvio padrão de gastos com {item} foi {df[item].std()}')
    print(f'O máximo de gastos com {item} foi {df[item].max()}')
    print(f'O mínimo de gastos com {item} foi {df[item].min()}')
print('+--------------------------------------------------+')
# Out:
# +--------------------------------------------------+
# A soma de gastos com mostarda foi 46.0
# A média de gastos com mostarda foi 11.5
# O desvio padrão de gastos com mostarda foi 2.3804761428476167
# O máximo de gastos com mostarda foi 15.0
# O mínimo de gastos com mostarda foi 10.0
# +--------------------------------------------------+
# A soma de gastos com kethchup foi 63.0
# A média de gastos com kethchup foi 15.75
# O desvio padrão de gastos com kethchup foi 6.238322424070967
# O máximo de gastos com kethchup foi 22.0
# O mínimo de gastos com kethchup foi 9.0
# +--------------------------------------------------+
# A soma de gastos com maçã foi 72.0
# A média de gastos com maçã foi 18.0
# O desvio padrão de gastos com maçã foi 4.96655480858378
# O máximo de gastos com maçã foi 25.0
# O mínimo de gastos com maçã foi 14.0
# +--------------------------------------------------+
# A soma de gastos com banana foi 110.0
# A média de gastos com banana foi 27.5
# ...

# %% [markdown]
# # Trabalhando com arquivos .csv

# %% [markdown]
# Importando os dados a partir de um arquivo '<i>.csv</i>' contendo dados do IGM preparado especificamente para usarmos neste treinamento.
# Em nosso código esse arquivo ficará salvo com o nome de `igm`
# Esse arquivo foi construído a partir de uma série de colunas que compõe o IGM e também de notas do ENEM e está disponível em nosso link do Github

# %%
url = 'https://raw.githubusercontent.com/DeepFluxion/CursoPythonEcogen/main/data/igm_modificado.csv' 
igm = pd.read_csv(url)

# %% [markdown]
# Temos uma variável chamada `igm` que está guardando algo, para descobrirmos basta digitar `igm` e apertar `Shift + Enter`:

# %% [markdown]
# # Primeiro Contato com os Dados

# %% [markdown]
# Uma das primeiras coisas a se fazer quando se pega um conjunto de dados novo é uma rápida visualização a fim de entender melhor o que tem dentro dele.

# %%
igm
# Out:
#             regiao estado                municipio  codigo_mun  capital  \
# 0          SUDESTE     SP                 ILHABELA     3520400        0
# 1          SUDESTE     SP      SANTANA DE PARNAIBA     3547304        0
# 2              SUL     SC                BOMBINHAS     4202453        0
# 3          SUDESTE     SP    SAO BERNARDO DO CAMPO     3548708        0
# 4     CENTRO-OESTE     DF                 BRASILIA     5300108        1
# ...            ...    ...                      ...         ...      ...
# 5565         NORTE     TO             RIO DOS BOIS     1718709        0
# 5566         NORTE     TO       AXIXA DO TOCANTINS     1702901        0
# 5567         NORTE     TO               FILADELFIA     1707702        0
# 5568         NORTE     TO  PONTE ALTA DO TOCANTINS     1717909        0
# 5569         NORTE     TO             SILVANOPOLIS     1720655        0
#
#                 porte  populacao      area densidade_dem           pib  ...  \
# ...

# %% [markdown]
# ## Dissecando o DataFrame (Tipo de Dados)

# %% [markdown]
# A visualização do DataFrame acima é composta pelos seguintes elementos:
#
#     1. Index
#     2. Elemento do Index
#     3. Colunas
#     4. Nome da coluna (pode ter espaço, acento e etc, mas nome curto, simples, e representativo facilita o código)
#     5. '...'
#     6. Células (Dados)
#     7. NaNs

# %% [markdown]
# Para vermos apenas uma pequena parte, temos o comando `.head()` irá mostrar por padrão as 5 primeiras linhas do que existe dentro de um conjunto de dados dentro de um objeto do pandas.

# %%
igm.head()
# Out:
#          regiao estado              municipio  codigo_mun  capital  \
# 0       SUDESTE     SP               ILHABELA     3520400        0
# 1       SUDESTE     SP    SANTANA DE PARNAIBA     3547304        0
# 2           SUL     SC              BOMBINHAS     4202453        0
# 3       SUDESTE     SP  SAO BERNARDO DO CAMPO     3548708        0
# 4  CENTRO-OESTE     DF               BRASILIA     5300108        1
#
#              porte  populacao      area densidade_dem           pib  ...  \
# 0  Pequeno porte 2     32,782    347.52          81.1  3.256712e+06  ...
# 1     Grande porte    129,261    179.95         604.7  7.373603e+06  ...
# 2  Pequeno porte 1     18,052     35.92           398  3.773573e+05  ...
# 3     Grande porte    822,242    409.53      1,869.40  4.766853e+07  ...
# 4     Grande porte  2,977,216  5,780.00         444.7  1.753628e+08  ...
#
#    gasto_pc_educacao  exp_anos_estudo  nota_ciencias  nota_humanas  \
# ...

# %% [markdown]
# ## Outras formas de selecionar uma pequena amostra de dados:

# %% [markdown]
# O comando inverso ao `head()` é o `tail()`, que irá mostrar as 5 __últimas__ linhas do DataFrame por padrão:

# %%
igm.tail()
# Out:
#      regiao estado                municipio  codigo_mun  capital  \
# 5565  NORTE     TO             RIO DOS BOIS     1718709        0
# 5566  NORTE     TO       AXIXA DO TOCANTINS     1702901        0
# 5567  NORTE     TO               FILADELFIA     1707702        0
# 5568  NORTE     TO  PONTE ALTA DO TOCANTINS     1717909        0
# 5569  NORTE     TO             SILVANOPOLIS     1720655        0
#
#                 porte populacao      area densidade_dem       pib  ...  \
# 5565  Pequeno porte 1     2,787    845.07             3  27136.71  ...
# 5566  Pequeno porte 1     9,741    150.21          61.8  80205.45  ...
# 5567  Pequeno porte 1     8,871  1,988.08           4.3  78500.72  ...
# 5568  Pequeno porte 1     7,872  6,491.13           1.1  59147.57  ...
# 5569  Pequeno porte 1     5,372  1,258.83             4  77734.86  ...
#
#       gasto_pc_educacao  exp_anos_estudo  nota_ciencias  nota_humanas  \
# 5565                NaN             9.26     450.613333    457.100000
# ...

# %% [markdown]
# Apesar da convenção no Python ser utilizar o `.head()` ou o `.tail()` para olhar um DataFrame novo, algo muito mais inteligente de se fazer para ter uma ideia representativa do DataFrame é utilizar o `sample(5)`, que seleciona 5 linhas aleatórias do seu `DataFrame`. Se você executar o comando algumas vezes vai obter resultados diferentes a cada iteração.

# %%
igm.sample(5)
# Out:
#             regiao estado       municipio  codigo_mun  capital  \
# 3999       SUDESTE     MG       RITAPOLIS     3156106        0
# 4029  CENTRO-OESTE     GO      AGUA LIMPA     5200209        0
# 1676       SUDESTE     MG       HELIODORA     3129202        0
# 3255      NORDESTE     MA  CANDIDO MENDES     2102606        0
# 3462           SUL     SC      CAPAO ALTO     4203253        0
#
#                 porte populacao      area densidade_dem       pib  ...  \
# 3999  Pequeno porte 1     4,862    404.81          12.2  44083.77  ...
# 4029  Pequeno porte 1     1,980    452.86           4.5  41701.34  ...
# 1676  Pequeno porte 1     6,528    153.95          39.8  68843.48  ...
# 3255  Pequeno porte 1    19,827  1,640.76          11.3  87526.41  ...
# 3462  Pequeno porte 1     2,625  1,335.84           2.1  99699.71  ...
#
#       gasto_pc_educacao  exp_anos_estudo  nota_ciencias  nota_humanas  \
# 3999             481.99             9.47     496.039394    547.927273
# ...

# %% [markdown]
# ## Melhorando a visualização da tabela

# %% [markdown]
# Um truque para visualizar melhor os dados é invertendo as linhas pelas colunas (matrix transposta), para isso basta colocar um `.T` depois do nosso comando que gera uma visualização de DataFrame.

# %%
igm.T
# Out:
#                                         0                    1     \
# regiao                               SUDESTE              SUDESTE
# estado                                    SP                   SP
# municipio                           ILHABELA  SANTANA DE PARNAIBA
# codigo_mun                           3520400              3547304
# capital                                    0                    0
# porte                        Pequeno porte 2         Grande porte
# populacao                             32,782              129,261
# area                                  347.52               179.95
# densidade_dem                           81.1                604.7
# pib                               3256711.64           7373602.99
# pib_pc                             105112.86             60939.87
# participacao_transf_receita             77.0                 51.0
# servidores                            1495.0               6157.0
# ...

# %% [markdown]
# ## Encadeamento de funcionalidades

# %% [markdown]
# Podemos juntar diversos comando na mesma linha, isto é, logo após o `sample(5)`, pode usar o `.T`, e essas funcionalidades irão funcionar em cascata e de forma sequêncial, primeiro o `sample(5)`, e depois o `.T`

# %%
igm.sample(5).T
# Out:
#                                           3819             4472  \
# regiao                                 SUDESTE         NORDESTE
# estado                                      SP               BA
# municipio                    BARAO DE ANTONINA            ABARE
# codigo_mun                             3505005          2900207
# capital                                      0                0
# porte                          Pequeno porte 1  Pequeno porte 1
# populacao                                3,380           19,939
# area                                    153.14         1,484.87
# densidade_dem                             20.4             11.5
# pib                                   54271.55         92554.32
# pib_pc                                16460.89           4874.1
# participacao_transf_receita               91.0             90.0
# servidores                               178.0            576.0
# comissionados                              7.0            110.0
# ...

# %% [markdown]
# ## Selecionando Linhas no pandas

# %% [markdown]
# Outra forma de vermos os 5 primeiros registros podemos usar o comando:

# %%
igm[0:5].T
# Out:
#                                            0                    1  \
# regiao                               SUDESTE              SUDESTE
# estado                                    SP                   SP
# municipio                           ILHABELA  SANTANA DE PARNAIBA
# codigo_mun                           3520400              3547304
# capital                                    0                    0
# porte                        Pequeno porte 2         Grande porte
# populacao                             32,782              129,261
# area                                  347.52               179.95
# densidade_dem                           81.1                604.7
# pib                               3256711.64           7373602.99
# pib_pc                             105112.86             60939.87
# participacao_transf_receita             77.0                 51.0
# servidores                            1495.0               6157.0
# ...

# %% [markdown]
# Outra forma de vermos os cinco últimos comandos é:

# %%
igm[-5:].T
# Out:
#                                         5565                5566  \
# regiao                                 NORTE               NORTE
# estado                                    TO                  TO
# municipio                       RIO DOS BOIS  AXIXA DO TOCANTINS
# codigo_mun                           1718709             1702901
# capital                                    0                   0
# porte                        Pequeno porte 1     Pequeno porte 1
# populacao                              2,787               9,741
# area                                  845.07              150.21
# densidade_dem                              3                61.8
# pib                                 27136.71            80205.45
# pib_pc                               9995.11             8326.98
# participacao_transf_receita              NaN                 NaN
# servidores                              98.0               429.0
# ...

# %% [markdown]
# A vantagem da forma explicitada acima é que podemos selecionar qualquer local da tabela, não estando restritos as primeiras linhas. Por exemplo, o comando a seguir seleciona as linhas 20 até 29:

# %%
igm[20:30].T
# Out:
#                                           20            21               22  \
# regiao                                   SUL       SUDESTE     CENTRO-OESTE
# estado                                    RS            RJ               GO
# municipio                            TUPANDI       NITEROI  CHAPADAO DO CEU
# codigo_mun                           4322251       3303302          5205471
# capital                                    0             0                0
# porte                        Pequeno porte 1  Grande porte  Pequeno porte 1
# populacao                              4,421       497,883            8,853
# area                                   59.54        133.92         2,185.12
# densidade_dem                           65.9      3,640.80              3.2
# pib                                315219.63   19908508.36        920448.16
# pib_pc                              74204.24      40284.31        114455.13
# ...

# %% [markdown]
# ## Slicing no Pandas

# %% [markdown]
# O nome dessa operação de colocar algo entre colchetes é slicing, e isso como convenção geral é uma forma de selecionar um subconjunto de dados.

# %% [markdown]
# [20:30] vai selecionar exatamente 10 elementos (30 - 20). O número da direita menos o número da esquerda é sempre o total de elementos que serão selecionados, e isso é uma convenção no Python.
#
# O número 20 é selecionado por ser um intervalo fechado na esquerda, e o número 30 não é selecionado por ser um intervalo aberto na direita. O que é outra convenção do Python.

# %% [markdown]
# ## Selecionando colunas

# %% [markdown]
# Para selecionarmos colunas no pandas, basta dizermos o nome do DataFrame seguido por colchetes com o nome da coluna dentro:
#
# __Nome do Dataframe:__ `igm`
#
# __Colchetes com a coluna dentro:__ `['Porte do Município']`
#
# __Comando completo:__ `igm['Porte do Município']`

# %%
igm['porte']
# Out:
# 0       Pequeno porte 2
# 1          Grande porte
# 2       Pequeno porte 1
# 3          Grande porte
# 4          Grande porte
#              ...
# 5565    Pequeno porte 1
# 5566    Pequeno porte 1
# 5567    Pequeno porte 1
# 5568    Pequeno porte 1
# 5569    Pequeno porte 1
# Name: porte, Length: 5570, dtype: object

# %% [markdown]
# ## Selecionando Múltiplas Colunas

# %% [markdown]
# Podemos selecionar multiplas colunas com o comando `igm[['municipio', 'indice_governanca']]`:

# %%
igm[['municipio', 'indice_governanca']]
# Out:
#                     municipio  indice_governanca
# 0                    ILHABELA              0.767
# 1         SANTANA DE PARNAIBA              0.759
# 2                   BOMBINHAS              0.758
# 3       SAO BERNARDO DO CAMPO              0.756
# 4                    BRASILIA              0.736
# ...                       ...                ...
# 5565             RIO DOS BOIS                NaN
# 5566       AXIXA DO TOCANTINS                NaN
# 5567               FILADELFIA                NaN
# 5568  PONTE ALTA DO TOCANTINS                NaN
# 5569             SILVANOPOLIS                NaN
#
# [5570 rows x 2 columns]

# %% [markdown]
# ##  `Exercícios: Seleções Básicas`

# %% [markdown]
# 1. Selecionar as 10 primeiras linhas mostrando as colunas `municipio`, `estado` e `idhm`.
# 2. Selecionar das linhas 15 a 24 os valores da coluna `municipio`

# %% [markdown]
# ## Dissecando Series (Tipo de Dados)

# %%
type(igm['porte'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Quando selecionamos uma coluna, o nosso resultado é um objeto do tipo `Series`, que é basicamente a forma do pandas representar uma coluna. Uma `Series` é composta pelos seguintes elementos:
#     1. Index
#     2. Index label
#     3. Hidden values
#     4. Series Name
#     5. Lenght
#     6. dtype

# %% [markdown]
# # Fazendo Operações de Agregamento:

# %% [markdown]
# Vamos contar quantos valores da coluna `porte` temos para cada tipo com o comando `value_counts()`:

# %%
igm['porte'].value_counts()
# Out:
# porte
# Pequeno porte 1    3810
# Pequeno porte 2    1101
# Médio porte         350
# Grande porte        309
# Name: count, dtype: int64

# %% [markdown]
# ## Plotando Nosso Primeiro Gráfico

# %% [markdown]
# Para garantir que nossos gráficos vão ser plotados em todas as versões do `Jupyter Notebook` precisamos rodar o comando abaixo:

# %%
# %matplotlib inline

# %% [markdown]
# Com bastante facilidade podemos plotar um gráfico com os valores acima, basta colocar `.plot.bar()` na sequência.

# %%
igm['porte'].value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='porte'>

# %% [markdown]
# ##  `Desafios: Series`

# %% [markdown]
# 1. Contar o número de munícipios por estado
# 2. Plotar gráfico de número de munícipios por estado

# %% [markdown]
# ## Operações de Agregamento Numéricas

# %% [markdown]
# Vamos criar uma variável chamada `ind_des` para guarda a nossa `Series` relativa a coluna `indice_governanca`

# %%
ind_des = igm['indice_governanca']

# %% [markdown]
# Vamos contar a quantidade de elementos em `ind_des`

# %% [markdown]
# Para verificarmos quais são os valores em branco podemos usar o `isnull()`, que nos retornar uma `Series` com valores `True` ou `False` de acordo com se os valores estiverem em branco ou não.

# %%
ind_des.count()
# Out:
# 3303

# %% [markdown]
# Note que o `.count()` não contabiliza valores em branco, se quisermos ver os valores em branco temos que usar o atributo `.size`, que não tem paranteses

# %%
ind_des.size
# Out:
# 5570

# %%
ind_des.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5565     True
# 5566     True
# 5567     True
# 5568     True
# 5569     True
# Name: indice_governanca, Length: 5570, dtype: bool

# %% [markdown]
# Uma forma de melhor utilizarmos essa informação é contabilizando o total de valores em branco, note que `True` tem valor `1` e `False` tem valor `0`, portanto se somarmos todos os elementos, teremos o total de valores em branco.

# %%
ind_des.isnull().sum()
# Out:
# 2267

# %% [markdown]
# Podemos remover esses valores em branco com um simples comando, o `dropna()`.

# %%
ind_des.dropna()
# Out:
# 0       0.767
# 1       0.759
# 2       0.758
# 3       0.756
# 4       0.736
#         ...
# 3298    0.296
# 3299    0.282
# 3300    0.279
# 3301    0.278
# 3302    0.258
# Name: indice_governanca, Length: 3303, dtype: float64

# %% [markdown]
# Ele retornou os valores, e podemos ver que não tem nenhum valor em branco, mas vamos verificar de fato para ver se mudamos os nossos valores:

# %%
ind_des.isnull().sum()
# Out:
# 2267

# %% [markdown]
# Não mudou, por que isso aconteceu? Uma série de funções no pandas não alteram o objeto em questão, porque muitas vezes estamos fazendo transformações temporárias para gerar uma visualização ou análise, para mudar o objeto temos que passar um parâmetro a mais que é o `inplace=True`.

# %%
ind_des.dropna(inplace=True)

# %% [markdown]
# Vamos verificar novamente se temos valores em branco no nosso conjunto de dados:

# %%
ind_des.isnull().sum()
# Out:
# 0

# %% [markdown]
# Selecionando o valor mínimo do índice de desempenho

# %%
ind_des.min()
# Out:
# 0.258

# %% [markdown]
# Selecionando o valor máximo do índice de desempenho

# %%
ind_des.max()
# Out:
# 0.767

# %% [markdown]
# Olhando a média dos valores:

# %%
ind_des.mean()
# Out:
# 0.5019585225552529

# %% [markdown]
# Olhando o desvio padrão dos valores:

# %%
ind_des.std()
# Out:
# 0.08370404317359417

# %% [markdown]
# ## Tendo uma visão geral do Índice de Governança

# %% [markdown]
# Um comando muito útil para avaliar uma `Series` é o `.describe()`, que irá calcular os quartis, valores máximo, mínimo, a média e o desvio padrão.

# %%
ind_des.describe()
# Out:
# count    3303.000000
# mean        0.501959
# std         0.083704
# min         0.258000
# 25%         0.438000
# 50%         0.504000
# 75%         0.566000
# max         0.767000
# Name: indice_governanca, dtype: float64

# %% [markdown]
# ## Usando o .describe() em um DataFrame

# %% [markdown]
# O bom é que o `describe()` também funciona em um `DataFrame`, e por padrão apenas para as colunas numéricas:

# %%
igm.describe()
# Out:
#          codigo_mun      capital           pib         pib_pc  \
# count  5.570000e+03  5570.000000  5.570000e+03    5570.000000
# mean   3.253591e+06     0.004847  9.544801e+05   17374.483108
# std    9.849103e+05     0.069461  9.502661e+06   20133.341193
# min    1.100015e+06     0.000000  9.678440e+03    3241.290000
# 25%    2.512126e+06     0.000000  5.922529e+04    7077.357500
# 50%    3.146280e+06     0.000000  1.301531e+05   12621.810000
# 75%    4.119190e+06     0.000000  3.426808e+05   21262.387500
# max    5.300108e+06     1.000000  5.707062e+08  715193.700000
#
#        participacao_transf_receita     servidores  comissionados  \
# count                  4893.000000    5233.000000    5570.000000
# mean                     82.316575     771.324861      96.371275
# std                      11.272136    3209.755931     234.994469
# min                       0.000000       1.000000       0.000000
# 25%                      77.000000     190.000000      24.000000
# ...

# %% [markdown]
# ##  `Desafios: Agregações Númericas`

# %% [markdown]
# 1. Utilize o `.min()`, `.max()`, e `.mean()` para avaliar os dados da coluna `exp_vida`
# 2. Utilize o `.describe()` para avaliar os dados da coluna `idhm`

# %% [markdown]
# ## Plotando um Histograma do Índice de Governança

# %%
ind_des.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Excelente se você conseguiu chegar aqui sem problemas parabéns 🤩🙌👏
# 🧑‍🎓🧑🏿‍🎓🧑🏻‍🎓🧑🏾‍🎓🧑🏼‍🎓🧑🏽‍🎓
#
# Muita coisa nessa sexta conversa!! Nos aprofundamos em funções, um recurso muito importante dentro do python!
# Hoje conhecemos o Pandas uma das principais bibliotes de análise de dados, vimos algumas operações básicas, mas na próxima conversa veremos muito mais!
